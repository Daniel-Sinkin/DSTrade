# %%
from pathlib import Path

import requests
from bs4 import BeautifulSoup

# URL of the Alpha Vantage documentation
url = "https://www.alphavantage.co/documentation/"

# Fetch the page content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
else:
    print(f"Failed to fetch the page. Status code: {response.status_code}")
    raise RuntimeError

request_base_url = "https://www.alphavantage.co/query?function="
lines = [line for line in soup.text.splitlines() if line.startswith(request_base_url)]

examples: dict[str, list[dict[str, str]]] = {}
for line in lines:
    split = line.removeprefix(request_base_url).split("&")[:-1]
    function = split[0]
    if function not in examples:
        examples[function] = []
    args = split[1:]
    examples[function].append(args)

handler_name = "handler"
for func, args in examples.items():
    print(f"def test_{func.lower()}() -> None")
    for arg in args:
        arg = [f'"{a}"' for a in arg]
        print(f"    assert {handler_name}.{func.lower()}({', '.join(arg)}) is not None")
    print()

# %%
examples
# Out:
# {'TIME_SERIES_INTRADAY': [['symbol=IBM', 'interval=5min'],
#   ['symbol=IBM', 'interval=5min', 'outputsize=full'],
#   ['symbol=IBM', 'interval=5min', 'month=2009-01', 'outputsize=full']],
#  'TIME_SERIES_DAILY': [['symbol=IBM'],
#   ['symbol=IBM', 'outputsize=full'],
#   ['symbol=TSCO.LON', 'outputsize=full'],
#   ['symbol=SHOP.TRT', 'outputsize=full'],
#   ['symbol=GPV.TRV', 'outputsize=full'],
#   ['symbol=MBG.DEX', 'outputsize=full'],
#   ['symbol=RELIANCE.BSE', 'outputsize=full'],
#   ['symbol=600104.SHH', 'outputsize=full'],
#   ['symbol=000002.SHZ', 'outputsize=full']],
#  'TIME_SERIES_DAILY_ADJUSTED': [['symbol=IBM'],
#   ['symbol=IBM', 'outputsize=full'],
#   ['symbol=TSCO.LON', 'outputsize=full'],
#   ['symbol=SHOP.TRT', 'outputsize=full'],
#   ['symbol=GPV.TRV', 'outputsize=full'],
#   ['symbol=MBG.DEX', 'outputsize=full'],
#   ['symbol=RELIANCE.BSE', 'outputsize=full'],
#   ['symbol=600104.SHH', 'outputsize=full'],
#   ['symbol=000002.SHZ', 'outputsize=full']],
#  'TIME_SERIES_WEEKLY': [['symbol=IBM'], ['symbol=TSCO.LON']],
#  'TIME_SERIES_WEEKLY_ADJUSTED': [['symbol=IBM'], ['symbol=TSCO.LON']],
#  'TIME_SERIES_MONTHLY': [['symbol=IBM'], ['symbol=TSCO.LON']],
#  'TIME_SERIES_MONTHLY_ADJUSTED': [['symbol=IBM'], ['symbol=TSCO.LON']],
#  'GLOBAL_QUOTE': [['symbol=IBM'], ['symbol=300135.SHZ']],
#  'REALTIME_BULK_QUOTES': [['symbol=MSFT,AAPL,IBM']],
#  'SYMBOL_SEARCH': [['keywords=tesco'],
#   ['keywords=tencent'],
#   ['keywords=BA'],
#   ['keywords=SAIC']],
#  'MARKET_STATUS': [[]],
#  'REALTIME_OPTIONS': [['symbol=IBM']],
#  'HISTORICAL_OPTIONS': [['symbol=IBM'], ['symbol=IBM', 'date=2017-11-15']],
#  'NEWS_SENTIMENT': [['tickers=AAPL'],
#   ['tickers=COIN,CRYPTO:BTC,FOREX:USD',
#    'time_from=20220410T0130',
#    'limit=1000']],
#  'TOP_GAINERS_LOSERS': [[]],
#  'INSIDER_TRANSACTIONS': [['symbol=IBM']],
#  'ANALYTICS_FIXED_WINDOW': [['SYMBOLS=AAPL,MSFT,IBM',
#    'RANGE=2023-07-01',
#    'RANGE=2023-08-31',
#    'INTERVAL=DAILY',
#    'OHLC=close',
#    'CALCULATIONS=MEAN,STDDEV,CORRELATION']],
#  'ANALYTICS_SLIDING_WINDOW': [['SYMBOLS=AAPL,IBM',
#    'RANGE=2month',
#    'INTERVAL=DAILY',
#    'OHLC=close',
#    'WINDOW_SIZE=20',
#    'CALCULATIONS=MEAN,STDDEV(annualized=True)']],
#  'OVERVIEW': [['symbol=IBM']],
#  'ETF_PROFILE': [['symbol=QQQ']],
#  'DIVIDENDS': [['symbol=IBM']],
#  'SPLITS': [['symbol=IBM']],
#  'INCOME_STATEMENT': [['symbol=IBM']],
#  'BALANCE_SHEET': [['symbol=IBM']],
#  'CASH_FLOW': [['symbol=IBM']],
#  'EARNINGS': [['symbol=IBM']],
#  'FX_INTRADAY': [['from_symbol=EUR', 'to_symbol=USD', 'interval=5min'],
#   ['from_symbol=EUR', 'to_symbol=USD', 'interval=5min', 'outputsize=full']],
#  'FX_DAILY': [['from_symbol=EUR', 'to_symbol=USD'],
#   ['from_symbol=EUR', 'to_symbol=USD', 'outputsize=full']],
#  'FX_WEEKLY': [['from_symbol=EUR', 'to_symbol=USD']],
#  'FX_MONTHLY': [['from_symbol=EUR', 'to_symbol=USD']],
#  'CRYPTO_INTRADAY': [['symbol=ETH', 'market=USD', 'interval=5min'],
#   ['symbol=ETH', 'market=USD', 'interval=5min', 'outputsize=full']],
#  'DIGITAL_CURRENCY_DAILY': [['symbol=BTC', 'market=EUR']],
#  'DIGITAL_CURRENCY_WEEKLY': [['symbol=BTC', 'market=EUR']],
#  'DIGITAL_CURRENCY_MONTHLY': [['symbol=BTC', 'market=EUR']],
#  'WTI': [['interval=monthly']],
#  'BRENT': [['interval=monthly']],
#  'NATURAL_GAS': [['interval=monthly']],
#  'COPPER': [['interval=monthly']],
#  'ALUMINUM': [['interval=monthly']],
#  'WHEAT': [['interval=monthly']],
#  'CORN': [['interval=monthly']],
#  'COTTON': [['interval=monthly']],
#  'SUGAR': [['interval=monthly']],
#  'COFFEE': [['interval=monthly']],
#  'ALL_COMMODITIES': [['interval=monthly']],
#  'REAL_GDP': [['interval=annual']],
#  'REAL_GDP_PER_CAPITA': [[]],
#  'TREASURY_YIELD': [['interval=monthly', 'maturity=10year']],
#  'FEDERAL_FUNDS_RATE': [['interval=monthly']],
#  'CPI': [['interval=monthly']],
#  'INFLATION': [[]],
#  'RETAIL_SALES': [[]],
#  'DURABLES': [[]],
#  'UNEMPLOYMENT': [[]],
#  'NONFARM_PAYROLL': [[]],
#  'WMA': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=open']],
#  'DEMA': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=open']],
#  'TEMA': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=open']],
#  'TRIMA': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=open']],
#  'KAMA': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=open']],
#  'MAMA': [['symbol=IBM',
#    'interval=daily',
#    'series_type=close',
#    'fastlimit=0.02']],
#  'VWAP': [['symbol=IBM', 'interval=15min']],
#  'T3': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=open']],
#  'MACDEXT': [['symbol=IBM', 'interval=daily', 'series_type=open']],
#  'STOCHF': [['symbol=IBM', 'interval=daily']],
#  'STOCHRSI': [['symbol=IBM',
#    'interval=daily',
#    'time_period=10',
#    'series_type=close',
#    'fastkperiod=6',
#    'fastdmatype=1']],
#  'WILLR': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'ADXR': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'APO': [['symbol=IBM',
#    'interval=daily',
#    'series_type=close',
#    'fastperiod=10',
#    'matype=1']],
#  'PPO': [['symbol=IBM',
#    'interval=daily',
#    'series_type=close',
#    'fastperiod=10',
#    'matype=1']],
#  'MOM': [['symbol=IBM',
#    'interval=daily',
#    'time_period=10',
#    'series_type=close']],
#  'BOP': [['symbol=IBM', 'interval=daily']],
#  'CMO': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=close']],
#  'ROC': [['symbol=IBM',
#    'interval=weekly',
#    'time_period=10',
#    'series_type=close']],
#  'ROCR': [['symbol=IBM',
#    'interval=daily',
#    'time_period=10',
#    'series_type=close']],
#  'AROONOSC': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'MFI': [['symbol=IBM', 'interval=weekly', 'time_period=10']],
#  'TRIX': [['symbol=IBM',
#    'interval=daily',
#    'time_period=10',
#    'series_type=close']],
#  'ULTOSC': [['symbol=IBM', 'interval=daily', 'timeperiod1=8'],
#   ['symbol=IBM', 'interval=daily']],
#  'DX': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'MINUS_DI': [['symbol=IBM', 'interval=weekly', 'time_period=10']],
#  'PLUS_DI': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'MINUS_DM': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'PLUS_DM': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'MIDPOINT': [['symbol=IBM',
#    'interval=daily',
#    'time_period=10',
#    'series_type=close']],
#  'MIDPRICE': [['symbol=IBM', 'interval=daily', 'time_period=10']],
#  'SAR': [['symbol=IBM',
#    'interval=weekly',
#    'acceleration=0.05',
#    'maximum=0.25']],
#  'TRANGE': [['symbol=IBM', 'interval=daily']],
#  'ATR': [['symbol=IBM', 'interval=daily', 'time_period=14']],
#  'NATR': [['symbol=IBM', 'interval=weekly', 'time_period=14']],
#  'AD': [['symbol=IBM', 'interval=daily']],
#  'ADOSC': [['symbol=IBM', 'interval=daily', 'fastperiod=5']],
#  'OBV': [['symbol=IBM', 'interval=weekly']],
#  'HT_TRENDLINE': [['symbol=IBM', 'interval=daily', 'series_type=close']],
#  'HT_SINE': [['symbol=IBM', 'interval=daily', 'series_type=close']],
#  'HT_TRENDMODE': [['symbol=IBM', 'interval=weekly', 'series_type=close']],
#  'HT_DCPERIOD': [['symbol=IBM', 'interval=daily', 'series_type=close']],
#  'HT_DCPHASE': [['symbol=IBM', 'interval=daily', 'series_type=close']],
#  'HT_PHASOR': [['symbol=IBM', 'interval=weekly', 'series_type=close']]}

# %%
# Out:
# def test_time_series_intraday() -> None
#     assert handler.time_series_intraday("symbol=IBM", "interval=5min") is not None
#     assert handler.time_series_intraday("symbol=IBM", "interval=5min", "outputsize=full") is not None
#     assert handler.time_series_intraday("symbol=IBM", "interval=5min", "month=2009-01", "outputsize=full") is not None
#
# def test_time_series_daily() -> None
#     assert handler.time_series_daily("symbol=IBM") is not None
#     assert handler.time_series_daily("symbol=IBM", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=TSCO.LON", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=SHOP.TRT", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=GPV.TRV", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=MBG.DEX", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=RELIANCE.BSE", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=600104.SHH", "outputsize=full") is not None
#     assert handler.time_series_daily("symbol=000002.SHZ", "outputsize=full") is not None
#
# def test_time_series_daily_adjusted() -> None
#     assert handler.time_series_daily_adjusted("symbol=IBM") is not None
#     assert handler.time_series_daily_adjusted("symbol=IBM", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=TSCO.LON", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=SHOP.TRT", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=GPV.TRV", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=MBG.DEX", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=RELIANCE.BSE", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=600104.SHH", "outputsize=full") is not None
#     assert handler.time_series_daily_adjusted("symbol=000002.SHZ", "outputsize=full") is not None
#
# def test_time_series_weekly() -> None
#     assert handler.time_series_weekly("symbol=IBM") is not None
#     assert handler.time_series_weekly("symbol=TSCO.LON") is not None
#
# def test_time_series_weekly_adjusted() -> None
#     assert handler.time_series_weekly_adjusted("symbol=IBM") is not None
#     assert handler.time_series_weekly_adjusted("symbol=TSCO.LON") is not None
#
# def test_time_series_monthly() -> None
#     assert handler.time_series_monthly("symbol=IBM") is not None
#     assert handler.time_series_monthly("symbol=TSCO.LON") is not None
#
# def test_time_series_monthly_adjusted() -> None
#     assert handler.time_series_monthly_adjusted("symbol=IBM") is not None
#     assert handler.time_series_monthly_adjusted("symbol=TSCO.LON") is not None
#
# def test_global_quote() -> None
#     assert handler.global_quote("symbol=IBM") is not None
#     assert handler.global_quote("symbol=300135.SHZ") is not None
#
# def test_realtime_bulk_quotes() -> None
#     assert handler.realtime_bulk_quotes("symbol=MSFT,AAPL,IBM") is not None
#
# def test_symbol_search() -> None
#     assert handler.symbol_search("keywords=tesco") is not None
#     assert handler.symbol_search("keywords=tencent") is not None
#     assert handler.symbol_search("keywords=BA") is not None
#     assert handler.symbol_search("keywords=SAIC") is not None
#
# def test_market_status() -> None
#     assert handler.market_status() is not None
#
# def test_realtime_options() -> None
#     assert handler.realtime_options("symbol=IBM") is not None
#
# def test_historical_options() -> None
#     assert handler.historical_options("symbol=IBM") is not None
#     assert handler.historical_options("symbol=IBM", "date=2017-11-15") is not None
#
# def test_news_sentiment() -> None
#     assert handler.news_sentiment("tickers=AAPL") is not None
#     assert handler.news_sentiment("tickers=COIN,CRYPTO:BTC,FOREX:USD", "time_from=20220410T0130", "limit=1000") is not None
#
# def test_top_gainers_losers() -> None
#     assert handler.top_gainers_losers() is not None
#
# def test_insider_transactions() -> None
#     assert handler.insider_transactions("symbol=IBM") is not None
#
# def test_analytics_fixed_window() -> None
#     assert handler.analytics_fixed_window("SYMBOLS=AAPL,MSFT,IBM", "RANGE=2023-07-01", "RANGE=2023-08-31", "INTERVAL=DAILY", "OHLC=close", "CALCULATIONS=MEAN,STDDEV,CORRELATION") is not None
#
# def test_analytics_sliding_window() -> None
#     assert handler.analytics_sliding_window("SYMBOLS=AAPL,IBM", "RANGE=2month", "INTERVAL=DAILY", "OHLC=close", "WINDOW_SIZE=20", "CALCULATIONS=MEAN,STDDEV(annualized=True)") is not None
#
# def test_overview() -> None
#     assert handler.overview("symbol=IBM") is not None
#
# def test_etf_profile() -> None
#     assert handler.etf_profile("symbol=QQQ") is not None
#
# def test_dividends() -> None
#     assert handler.dividends("symbol=IBM") is not None
#
# def test_splits() -> None
#     assert handler.splits("symbol=IBM") is not None
#
# def test_income_statement() -> None
#     assert handler.income_statement("symbol=IBM") is not None
#
# def test_balance_sheet() -> None
#     assert handler.balance_sheet("symbol=IBM") is not None
#
# def test_cash_flow() -> None
#     assert handler.cash_flow("symbol=IBM") is not None
#
# def test_earnings() -> None
#     assert handler.earnings("symbol=IBM") is not None
#
# def test_fx_intraday() -> None
#     assert handler.fx_intraday("from_symbol=EUR", "to_symbol=USD", "interval=5min") is not None
#     assert handler.fx_intraday("from_symbol=EUR", "to_symbol=USD", "interval=5min", "outputsize=full") is not None
#
# def test_fx_daily() -> None
#     assert handler.fx_daily("from_symbol=EUR", "to_symbol=USD") is not None
#     assert handler.fx_daily("from_symbol=EUR", "to_symbol=USD", "outputsize=full") is not None
#
# def test_fx_weekly() -> None
#     assert handler.fx_weekly("from_symbol=EUR", "to_symbol=USD") is not None
#
# def test_fx_monthly() -> None
#     assert handler.fx_monthly("from_symbol=EUR", "to_symbol=USD") is not None
#
# def test_crypto_intraday() -> None
#     assert handler.crypto_intraday("symbol=ETH", "market=USD", "interval=5min") is not None
#     assert handler.crypto_intraday("symbol=ETH", "market=USD", "interval=5min", "outputsize=full") is not None
#
# def test_digital_currency_daily() -> None
#     assert handler.digital_currency_daily("symbol=BTC", "market=EUR") is not None
#
# def test_digital_currency_weekly() -> None
#     assert handler.digital_currency_weekly("symbol=BTC", "market=EUR") is not None
#
# def test_digital_currency_monthly() -> None
#     assert handler.digital_currency_monthly("symbol=BTC", "market=EUR") is not None
#
# def test_wti() -> None
#     assert handler.wti("interval=monthly") is not None
#
# def test_brent() -> None
#     assert handler.brent("interval=monthly") is not None
#
# def test_natural_gas() -> None
#     assert handler.natural_gas("interval=monthly") is not None
#
# def test_copper() -> None
#     assert handler.copper("interval=monthly") is not None
#
# def test_aluminum() -> None
#     assert handler.aluminum("interval=monthly") is not None
#
# def test_wheat() -> None
#     assert handler.wheat("interval=monthly") is not None
#
# def test_corn() -> None
#     assert handler.corn("interval=monthly") is not None
#
# def test_cotton() -> None
#     assert handler.cotton("interval=monthly") is not None
#
# def test_sugar() -> None
#     assert handler.sugar("interval=monthly") is not None
#
# def test_coffee() -> None
#     assert handler.coffee("interval=monthly") is not None
#
# def test_all_commodities() -> None
#     assert handler.all_commodities("interval=monthly") is not None
#
# def test_real_gdp() -> None
#     assert handler.real_gdp("interval=annual") is not None
#
# def test_real_gdp_per_capita() -> None
#     assert handler.real_gdp_per_capita() is not None
#
# def test_treasury_yield() -> None
#     assert handler.treasury_yield("interval=monthly", "maturity=10year") is not None
#
# def test_federal_funds_rate() -> None
#     assert handler.federal_funds_rate("interval=monthly") is not None
#
# def test_cpi() -> None
#     assert handler.cpi("interval=monthly") is not None
#
# def test_inflation() -> None
#     assert handler.inflation() is not None
#
# def test_retail_sales() -> None
#     assert handler.retail_sales() is not None
#
# def test_durables() -> None
#     assert handler.durables() is not None
#
# def test_unemployment() -> None
#     assert handler.unemployment() is not None
#
# def test_nonfarm_payroll() -> None
#     assert handler.nonfarm_payroll() is not None
#
# def test_wma() -> None
#     assert handler.wma("symbol=IBM", "interval=weekly", "time_period=10", "series_type=open") is not None
#
# def test_dema() -> None
#     assert handler.dema("symbol=IBM", "interval=weekly", "time_period=10", "series_type=open") is not None
#
# def test_tema() -> None
#     assert handler.tema("symbol=IBM", "interval=weekly", "time_period=10", "series_type=open") is not None
#
# def test_trima() -> None
#     assert handler.trima("symbol=IBM", "interval=weekly", "time_period=10", "series_type=open") is not None
#
# def test_kama() -> None
#     assert handler.kama("symbol=IBM", "interval=weekly", "time_period=10", "series_type=open") is not None
#
# def test_mama() -> None
#     assert handler.mama("symbol=IBM", "interval=daily", "series_type=close", "fastlimit=0.02") is not None
#
# def test_vwap() -> None
#     assert handler.vwap("symbol=IBM", "interval=15min") is not None
#
# def test_t3() -> None
#     assert handler.t3("symbol=IBM", "interval=weekly", "time_period=10", "series_type=open") is not None
#
# def test_macdext() -> None
#     assert handler.macdext("symbol=IBM", "interval=daily", "series_type=open") is not None
#
# def test_stochf() -> None
#     assert handler.stochf("symbol=IBM", "interval=daily") is not None
#
# def test_stochrsi() -> None
#     assert handler.stochrsi("symbol=IBM", "interval=daily", "time_period=10", "series_type=close", "fastkperiod=6", "fastdmatype=1") is not None
#
# def test_willr() -> None
#     assert handler.willr("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_adxr() -> None
#     assert handler.adxr("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_apo() -> None
#     assert handler.apo("symbol=IBM", "interval=daily", "series_type=close", "fastperiod=10", "matype=1") is not None
#
# def test_ppo() -> None
#     assert handler.ppo("symbol=IBM", "interval=daily", "series_type=close", "fastperiod=10", "matype=1") is not None
#
# def test_mom() -> None
#     assert handler.mom("symbol=IBM", "interval=daily", "time_period=10", "series_type=close") is not None
#
# def test_bop() -> None
#     assert handler.bop("symbol=IBM", "interval=daily") is not None
#
# def test_cmo() -> None
#     assert handler.cmo("symbol=IBM", "interval=weekly", "time_period=10", "series_type=close") is not None
#
# def test_roc() -> None
#     assert handler.roc("symbol=IBM", "interval=weekly", "time_period=10", "series_type=close") is not None
#
# def test_rocr() -> None
#     assert handler.rocr("symbol=IBM", "interval=daily", "time_period=10", "series_type=close") is not None
#
# def test_aroonosc() -> None
#     assert handler.aroonosc("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_mfi() -> None
#     assert handler.mfi("symbol=IBM", "interval=weekly", "time_period=10") is not None
#
# def test_trix() -> None
#     assert handler.trix("symbol=IBM", "interval=daily", "time_period=10", "series_type=close") is not None
#
# def test_ultosc() -> None
#     assert handler.ultosc("symbol=IBM", "interval=daily", "timeperiod1=8") is not None
#     assert handler.ultosc("symbol=IBM", "interval=daily") is not None
#
# def test_dx() -> None
#     assert handler.dx("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_minus_di() -> None
#     assert handler.minus_di("symbol=IBM", "interval=weekly", "time_period=10") is not None
#
# def test_plus_di() -> None
#     assert handler.plus_di("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_minus_dm() -> None
#     assert handler.minus_dm("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_plus_dm() -> None
#     assert handler.plus_dm("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_midpoint() -> None
#     assert handler.midpoint("symbol=IBM", "interval=daily", "time_period=10", "series_type=close") is not None
#
# def test_midprice() -> None
#     assert handler.midprice("symbol=IBM", "interval=daily", "time_period=10") is not None
#
# def test_sar() -> None
#     assert handler.sar("symbol=IBM", "interval=weekly", "acceleration=0.05", "maximum=0.25") is not None
#
# def test_trange() -> None
#     assert handler.trange("symbol=IBM", "interval=daily") is not None
#
# def test_atr() -> None
#     assert handler.atr("symbol=IBM", "interval=daily", "time_period=14") is not None
#
# def test_natr() -> None
#     assert handler.natr("symbol=IBM", "interval=weekly", "time_period=14") is not None
#
# def test_ad() -> None
#     assert handler.ad("symbol=IBM", "interval=daily") is not None
#
# def test_adosc() -> None
#     assert handler.adosc("symbol=IBM", "interval=daily", "fastperiod=5") is not None
#
# def test_obv() -> None
#     assert handler.obv("symbol=IBM", "interval=weekly") is not None
#
# def test_ht_trendline() -> None
#     assert handler.ht_trendline("symbol=IBM", "interval=daily", "series_type=close") is not None
#
# def test_ht_sine() -> None
#     assert handler.ht_sine("symbol=IBM", "interval=daily", "series_type=close") is not None
#
# def test_ht_trendmode() -> None
#     assert handler.ht_trendmode("symbol=IBM", "interval=weekly", "series_type=close") is not None
#
# def test_ht_dcperiod() -> None
#     assert handler.ht_dcperiod("symbol=IBM", "interval=daily", "series_type=close") is not None
#
# def test_ht_dcphase() -> None
#     assert handler.ht_dcphase("symbol=IBM", "interval=daily", "series_type=close") is not None
#
# def test_ht_phasor() -> None
#     assert handler.ht_phasor("symbol=IBM", "interval=weekly", "series_type=close") is not None
